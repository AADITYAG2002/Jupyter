# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
plt.figure(figsize=(12,12))
plt.xticks(rotation = 45)
sns.boxplot(df)
# Out:
# <AxesSubplot:>

# %%
data = df.drop(columns=['sepal length (cm)','sepal width (cm)'])
data.rename(columns={'petal length (cm)' : 'petal length',
                     'petal width (cm)' : 'petal width' }, inplace=True)
target = iris.target

# %%
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(data,target,test_size=0.25 )

# %%
kmeans = KMeans(n_clusters=3, random_state=0, n_init= "auto")
kmeans.fit(X_train)
labels_train = kmeans.labels_

# %%
colors = np.array(['red', 'blue', 'green'])
plt.scatter(X_train['petal length'],X_train['petal width'], c=colors[Y_train])
plt.show()

# %%
colors = np.array(['red', 'blue', 'green'])
plt.scatter(X_train['petal length'],X_train['petal width'], c=colors[labels_train])
plt.show()

# %%
prediction = kmeans.predict(X_test)
colors = np.array(['red', 'blue', 'green'])
plt.scatter(X_test['petal length'],X_test['petal width'], c=colors[Y_test])
plt.show()

# %%
colors = np.array(['red', 'blue', 'green'])
plt.scatter(X_test['petal length'],X_test['petal width'], c=colors[prediction])
plt.show()
